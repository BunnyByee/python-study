# %%
# %pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.27.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kimhi\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\kimhi\anaconda3\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\kimhi\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\kimhi\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sortedcontainers in c:\users\kimhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\kimhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\kimhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\kimhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\kimhi\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\kimhi\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\kimhi\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.27.1-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.7 MB 10.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.7 MB 11.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.7 MB 11.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.6 MB/s eta 0:00:00
# Downloading trio-0.27.0-py3-none-any.whl (481 kB)
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-24.3.0 outcome-1.3.0.post0 selenium-4.27.1 trio-0.27.0 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\kimhi\anaconda3\lib\site-packages (from webdriver_manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\kimhi\anaconda3\lib\site-packages (from webdriver_manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\kimhi\anaconda3\lib\site-packages (from webdriver_manager) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kimhi\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kimhi\anaconda3\lib\site-packages (from requests->webdriver_manager) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kimhi\anaconda3\lib\site-packages (from requests->webdriver_manager) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kimhi\anaconda3\lib\site-packages (from requests->webdriver_manager) (2024.8.30)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver_manager
# Successfully installed webdriver_manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time

# options 객체를 만들지 않으면 실행시 브라우저 창이 꺼짐
options = Options()
options.add_argument("--start-maximized") #창크기 최대화
options.add_experimental_option('detach', True)

driver = webdriver.Chrome(options=options)  

url = "https://www.naver.com/"
driver.get(url)

# %%
# 검색어 입력
driver.find_element(By.ID, 'query').send_keys('크리스마스 캐롤')
# 검색어 입력 후 2초 대기 
time.sleep(2)

# 검색버튼 클릭
search_btn = driver.find_element(By.CSS_SELECTOR,'#search-btn')
search_btn.click()

# # 엔터 쳐서 검색
# driver.find_element(By.ID,'query').send_keys(Keys.ENTER)
# time.sleep(2)

# 스크린샷
driver.save_screenshot('./crawling/스팩.png')

driver.quit()

# %%
search_item = input('상품명 또는 브랜드 입력 : ')

options = Options()
options.add_argument("--start-maximized") #창크기 최대화
options.add_experimental_option('detach', True)

driver = webdriver.Chrome(options=options)  

url2 = "https://shopping.naver.com/ns/home"
driver.get(url2)

driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > input').send_keys(search_item)
time.sleep(2)

search_btn2 = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > button._searchInput_button_search_wu9xq._nlog_click')
search_btn2.click()
time.sleep(2)

current_height = driver.execute_script("return window.scrollY")

count = 0

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    if count > 1:
        break
    count+=1
    
    current_height = scrolled_height

import requests
from bs4 import BeautifulSoup
import openpyxl

responce = requests.get(f'https://search.shopping.naver.com/ns/search?query={search_item}')
html = responce.text
soup = BeautifulSoup(html, 'html.parser')

all_li = soup.select('ul.compositeCardList_product_list__Ih4JR')
print(all_li)
# Out:
# []

# %%
from bs4 import BeautifulSoup

# 사용자 입력
search_item = input('상품명 또는 브랜드 입력: ')

# Selenium 설정
options = Options()
options.add_argument("--start-maximized")  # 창 최대화
options.add_experimental_option('detach', True)  # 브라우저 닫지 않음
driver = webdriver.Chrome(options=options)

# 네이버 쇼핑 페이지 열기
url = "https://shopping.naver.com/home"
driver.get(url)

# 검색창에 검색어 입력
driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > input').send_keys(search_item)
time.sleep(3)  # 페이지 로딩 대기

# 검색어 클릭
search_btn2 = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > button._searchInput_button_search_wu9xq._nlog_click')
search_btn2.click()
time.sleep(2)

# 스크롤 다운
current_height = driver.execute_script("return window.scrollY")

count = 0

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    if count > 1:
        break
    count+=1
    
    current_height = scrolled_height

import openpyxl
# 엑셀 만들기
wb = openpyxl.Workbook()

# 워크시트 만들기
ws = wb.active
ws.title = '쇼핑'

# 데이터 추가하기
ws.append(['상품명', '판매가', 'url'])

# 엑셀 저장하기
filePath = 'shopping.xlsx'

products = driver.find_elements(By.CSS_SELECTOR, '.basicProductCard_basic_product_card__TdrHT')

for product in products:
    # print("product",product)
    t = product.find_element(By.CSS_SELECTOR, '.basicProductCardInformation_title__Bc_Ng').text
    print(t)
    p = product.find_element(By.CSS_SELECTOR, '.priceTag_inner_price__TctbK').text.split()[0]    
    print(p)
    a = product.find_element(By.CSS_SELECTOR, '.basicProductCard_link__urzND')
    # print(a)
    l = a.get_attribute("href")
    print(l)
    ws.append([t, p, l])

wb.save(filePath)
# Out:
# 눈오리집게 스노우볼메이커 눈오리
# 3,580
# https://adcr.naver.com/adcr?x=PbGG5yiE11QlBwiFhAQOY////w==...#channelProductNo=9502944323
# 스노우볼 메이커 눈집게 만들기 (눈오리 중형 34cm)
# 3,000
# https://adcr.naver.com/adcr?x=4S7/zAV2K2a00q/xGkP1Rf///w==...#channelProductNo=6133806537
# 모래 뭉치기 눈오리 집게 스노우덕 메이커 클램프 타입 플라스틱 오리 눈틀 대형
# 2,680
# https://adcr.naver.com/adcr?x=XMZOU1zEcFB/yWvUX+j6IP///w==...#channelProductNo=8518817393
# 모래 뭉치기 눈오리 집게 스노우덕 메이커 클램프 타입 플라스틱 오리 눈틀 소형
# 1,330
# https://adcr.naver.com/adcr?x=7y5Vf3m5cuemhACK90s0Q////w==...#channelProductNo=8518817441
# KC 업그레이드 사이즈 눈오리 집게 스노우볼 메이커 스코프 눈뭉치 만들기 5종 모래장난감
# 2,900
# https://smartstore.naver.com/main/products/6067847321?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=cd929fa0600e44e09e8fd978c42e166a&NaPm=ci%3Dcd929fa0600e44e09e8fd978c42e166a%7Cct%3Dm4xmqpbt%7Ctr%3Dnslsl%7Csn%3D812657%7Chk%3D77fd62e79cff0eb7e2e110dfb391d33546557d45
# 스노우볼메이커 눈오리집게 눈뭉치제조기 눈사람만들기
# 2,040
# https://smartstore.naver.com/main/products/8012818939?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=4520149defb54a5683bd758317eebede&NaPm=ci%3D4520149defb54a5683bd758317eebede%7Cct%3Dm4xmqpbt%7Ctr%3Dnslsl%7Csn%3D988245%7Chk%3D0583afb69f9a4216c545c65af5b1adc50d15eaef
# 왕오리집게 대왕눈오리 초대형 41cm
# 4,700
# https://smartstore.naver.com/main/products/9609360042?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=51a7b0554d8f4c829c94598ba29c02eb&NaPm=ci%3D51a7b0554d8f4c829c94598ba29c02eb%7Cct%3Dm4xmqpbt%7Ctr%3Dnslsl%7Csn%3D9841174%7Chk%3De00f1a1cc41980e3636efcc78bea20e3506dbdd4
# 눈오리 집게 39cm 스노우볼메이커 눈뭉치 오리만들기 모래놀이 집게 JMJ
# 1,950
# https://smartstore.naver.com/main/products/7790625595?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=497235ff75c14d68b7aeb70a1bfab502&NaPm=ci%3D497235ff75c14d68b7aeb70a1bfab502%7Cct%3Dm4xmqpbt%7Ctr%3Dnslsl%7Csn%3D6821615%7Chk%3D5d0110e6b16c47e5b62cf4c16ae9459054ca1782
# 잔망루피 눈집게 8000 대형 눈오리 눈뭉치 만들기 스노우볼메이커
# 5,600
# https://smartstore.naver.com/main/products/7830705212?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au
nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=0a8f33858d514152b5578164188aa08d&NaPm=ci%3D0a8f33858d514152b5578164188aa08d%7Cct%3Dm4xmqq32%7Ctr%3Dnslsl%7Csn%3D383587%7Chk%3D8f701b744bb303aa86ba37e09975893611e6940f
# 6종 스노우볼 메이커 눈오리 공룡 눈사람 엄지 곰돌이 눈뭉치 제조기 대형
# 6,900
# https://smartstore.naver.com/main/products/6040685867?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=a4f58f3491af40fc8e6ab5cca9ab891b&NaPm=ci%3Da4f58f3491af40fc8e6ab5cca9ab891b%7Cct%3Dm4xmqq32%7Ctr%3Dnslsl%7Csn%3D326349%7Chk%3D23f2caca93b42fe9914583ed2a9b25da4b0d8726
# 로맨트리거 눈오리 눈사람 하트 집게
# 3,000
# https://smartstore.naver.com/main/products/6078397348?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=ee613a424976467ba5a015aefe31c620&NaPm=ci%3Dee613a424976467ba5a015aefe31c620%7Cct%3Dm4xmqq32%7Ctr%3Dnslsl%7Csn%3D3213738%7Chk%3Da5cb104dc4e3a296d0a38b4a80d1b79a87036b7e
# 스노우볼 메이커 제조기 눈오리 스노우덕 눈사람 오리만들기 집게 눈뭉치
# 990
# https://smartstore.naver.com/main/products/6015168644?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=bc45f49f410c48c9951b6887893802a0&NaPm=ci%3Dbc45f49f410c48c9951b6887893802a0%7Cct%3Dm4xmqq32%7Ctr%3Dnslsl%7Csn%3D2914588%7Chk%3Df83132c279f5177a633713ffba1d07ca6b66d217
# [비터베터] 눈집게 스노우볼메이커 눈오리 눈곰돌이 눈사람 눈뭉치 눈사람만들기
# 1,900
# https://smartstore.naver.com/main/products/7693524160?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=89bb7d590cf845488227fa442587e1c6&NaPm=ci%3D89bb7d590cf845488227fa442587e1c6%7Cct%3Dm4xmqq32%7Ctr%3Dnslsl%7Csn%3D1164191%7Chk%3D50805da37cb1c5ab9f3606d32a678df1110722f0
# 눈오리집게 스노우메이커 05공룡집게 대형
# 5,820
# https://adcr.naver.com/adcr?x=yt9YE7AvV3dBZUU8gsyvuP///w==...#channelProductNo=10504255265
# 눈사람 만들기 도구 눈덩이 제조기 오리 형상 눈집게 몇개 세트
# 1,530
# https://adcr.naver.com/adcr?x=VTYTJI35eu7ydEFZX8INvf///w==...#channelProductNo=11160846778
# 파이프박스 1+1 스노우볼 메이커 눈오리 집게 대형 오리눈사람 펭귄 틀 세트
# 5,900
# https://adcr.naver.com/adcr?x=CkkZbL0yd08VxGNmgCath////w==...#channelProductNo=6032055785
# 눈오리집게 스노우덕 눈사람 스노우볼메이커
# 2,000
# https://adcr.naver.com/adcr?x=jMjifSh44OsRFUgbfKZAuv///w==...#channelProductNo=5338869855
# 눈오리집게 34cm 대형 엄마오리집게 스노우덕메이커
# 4,500
# https://smartstore.naver.com/main/products/5339262610?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=4fd751fbf6dd4739a06b186268a3a386&NaPm=ci%3D4fd751fbf6dd4739a06b186268a3a386%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D924260%7Chk%3Dd0cccf9b3e93c5d17383d366eefdfbe2ca47e8be
# 스노우볼 메이커 눈뭉치 제조기 집게 [2종 축구공 모양 눈오리 뭉치기 틀 공]
# 990
# https://smartstore.naver.com/main/products/7719854929?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=8d989f7949394db98c6fa3fe7f6bc13b&NaPm=ci%3D8d989f7949394db98c6fa3fe7f6bc13b%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D382812%7Chk%3De3d8fb4ea3f5dd8d013c4487cc382ac1cecf1a9d
# 눈사람 곰돌이 만들기 눈 눈오리 모양 집게 겨울 스노우볼 장난감
# 3,150
# https://smartstore.naver.com/main/products/7671680480?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=692d310bc2354209b0c2bd5c600506ee&NaPm=ci%3D692d310bc2354209b0c2bd5c600506ee%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D615329%7Chk%3D89a978118b4db711b888db7cd5047453e40b49cb
# 오리 눈사람 스노우 볼 메이커 스노우덕 흰 눈 오리 집게 틀 만들기 뭉치 제조기 모양
# 2,800
# https://smartstore.naver.com/main/products/5866810994?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=ee27bec011324007931b08c2993b100a&NaPm=ci%3Dee27bec011324007931b08c2993b100a%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D2258999%7Chk%3De529e7a0ab470c16eef0957db4fc53907d3b9b61
# 흰눈오리 스노우메이커 눈오리집게 눈사람 곰돌이 겨울놀이아이템 모양틀
# 1,750
# https://smartstore.naver.com/main/products/6115085897?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=56072004ff304e71a63e9ba22f068e24&NaPm=ci%3D56072004ff304e71a63e9ba22f068e24%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D1132366%7Chk%3Df7590c2e4478643a1b996880a0f63a073d94413d
# 국산 무독성 스노우볼 메이커 눈오리집게 대형 38cm
# 3,000
# https://smartstore.naver.com/main/products/6062888776?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=5930d84d60ab4adcbbbd4e850449a8f1&NaPm=ci%3D5930d84d60ab4adcbbbd4e850449a8f1%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D1208898%7Chk%3Db2c6b2ec8f40a512caf0b67c801cf9f3837c0852
# 스노우볼 메이커 오리 눈사람 눈오리 집게
# 3,000
# https://smartstore.naver.com/main/products/6051413906?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=83bbc2d42a6a40aa98b00171f01a8624&NaPm=ci%3D83bbc2d42a6a40aa98b00171f01a8624%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D1197851%7Chk%3D3ca0fb0ada51e253837db19bd70eb80265307a45
# 눈집게 눈오리집게 스노우볼메이커
# 700
# https://smartstore.naver.com/main/products/7762838603?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=ae50187c84f34faf953d25b6f044ceb5&NaPm=ci%3Dae50187c84f34faf953d25b6f044ceb5%7Cct%3Dm4xmqq33%7Ctr%3Dnslsl%7Csn%3D3904878%7Chk%3Ddd1a169a9d4a539d5860ce2294ba2a2504e04736
# 눈오리집게 눈집게 러버덕 겨울 눈사람 만들기 스노우볼 메이커 장난감 크리스마스 선물
# 2,000
# https://adcr.naver.com/adcr?x=/GhMjes0u8Xi62e2rlhlV////w==...#channelProductNo=11180137399
# 눈뭉치 제조기 스노우볼 도구 축구공 모양 눈사람 오리 뭉치기
# 1,530
# https://adcr.naver.com/adcr?x=3mFH1f04mM/vRkSmAKYYoP///w==...#channelProductNo=11160943531
# 스노우볼 메이커 눈뭉치 제조기 눈오리 눈집게 스노우덕 눈사람 만들기
# 1,900
# https://adcr.naver.com/adcr?x=Nf0EvguElrpqDiYYANhEPv///w==...#channelProductNo=7686827033
# 젠카 눈 오리 집게 스노우볼 메이커 눈사람 만들기 스노우 덕 흰눈 눈뭉치 찍기 틀 제조기
# 780
# https://adcr.naver.com/adcr?x=sA3O68YzNAjosK8w6EO4Fv///w==...#channelProductNo=6133622814
# 곰돌이 눈집게[소] 스노우볼 메이커 눈오리 더블 하트 엄지척 눈사람 눈뭉치 만들기 제조기
# 1,190
# https://smartstore.naver.com/main/products/6090487587?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=adb65e9d39d646fdb28ac5cbfa269ede&NaPm=ci%3Dadb65e9d39d646fdb28ac5cbfa269ede%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D383587%7Chk%3D860c058a161ddcba0d7b968b1e8e216c67422269
# 눈오리 스노우 볼제조기 집게 눈사람 메이커 뭉치기 러버덕 함박눈 폭설 펑펑 겨울철 야외활동
# 2,100
# https://smartstore.naver.com/main/products/7524495381?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=05a89790e32345ea859355ea71d3e7c7&NaPm=ci%3D05a89790e32345ea859355ea71d3e7c7%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D3019138%7Chk%3Dd0202441b3fb7d2f61e4593d9f8dae7c48db411b
# 눈오리 집게 메이커 스노우덕 제조기 스노우볼 틀 눈사람 펭귄 수류탄 하트 곰돌이 별
# 1,600
# https://smartstore.naver.com/main/products/7738370004?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=62024db43a06495186f2c6b49c6f8fb6&NaPm=ci%3D62024db43a06495186f2c6b49c6f8fb6%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D823193%7Chk%3D5ecc654e0d3948bd04204e0390ad23a568dd07f4
# 눈오리 집게 눈오리메이커 랜덤색상
# 4,900
# https://smartstore.naver.com/main/products/5336438147?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=bddba961ddcc48e184981d1dc2443fca&NaPm=ci%3Dbddba961ddcc48e184981d1dc2443fca%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D1059845%7Chk%3De3b5c6c644da73db8b7a587d9e8081356e482e3b
# 눈오리 집게 스노우볼 메이커 눈 사람 하트 펭귄 뭉치 스노우덕
# 1,900
# https://smartstore.naver.com/main/products/5349246123?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=1f79f325039545b19b31b79051320ece&NaPm=ci%3D1f79f325039545b19b31b79051320ece%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D1056299%7Chk%3D052b67918cddffa745ece99c3efaef791fc03c59
# 눈뭉치기 스노우볼 눈사람 눈오리 틀 메이커
# 2,500
# https://smartstore.naver.com/main/products/6175434669?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=0ea299c9a6ab465aa6267bdf6e1ee665&NaPm=ci%3D0ea299c9a6ab465aa6267bdf6e1ee665%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D1066113%7Chk%3Da173560158a394131ce15b0850cb2fd2b225769c
# 대형눈오리 집게 펭귄 하트 별 공룡 초대형 집게 3단눈사람
# 3,000
# https://smartstore.naver.com/main/products/6091600777?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=f81d588511f44284b6fa311c971d2f12&NaPm=ci%3Df81d588511f44284b6fa311c971d2f12%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D4525262%7Chk%3D0b4c2a8ede48ee3a336fba78fd1d1cec758df73a
# 눈오리 집게 스노우볼메이커 특대형 눈뭉치 제조기
# 3,600
# https://smartstore.naver.com/main/products/7585791624?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=1d235a5e15264c16abed8081186c82a6&NaPm=ci%3D1d235a5e15264c16abed8081186c82a6%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D5177334%7Chk%3D20d4b46fdab79c76ae55558c807bccd27aea5591
# 스노우 메이커 오리 펭귄 하트 공룡 곰돌이 눈사람 만들기틀 눈뭉치 제조기
# 3,000
# https://smartstore.naver.com/main/products/6083329406?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=a048917fd62b4c32b6418368145c7ab1&NaPm=ci%3Da048917fd62b4c32b6418368145c7ab1%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D2057958%7Chk%3D8270b29d045843df0ea549ec56807028ba0ff626
# [1+1] 큰오리+작은오리 스노우볼 눈오리 메이커 집게
# 7,900
# https://smartstore.naver.com/main/products/6059987791?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=2eed188062774d8889aee6d0025bd13b&NaPm=ci%3D2eed188062774d8889aee6d0025bd13b%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D1014603%7Chk%3Daf83614d9dee424da287303060fc26df4da53ea6
# KC인증 눈오리집게하트미키마우스 스노우볼 메이커 눈뭉치제조기 눈놀이 스노우덕
# 5,900
# https://smartstore.naver.com/main/products/5364010105?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=d2ed8ca0a6634b0ebd29e2f54e301918&NaPm=ci%3Dd2ed8ca0a6634b0ebd29e2f54e301918%7Cct%3Dm4xmqq34%7Ctr%3Dnslsl%7Csn%3D868673%7Chk%3D59e8a2f2170e299bb5f1ffb2c689ef1e1f804329
# 오리모양 눈집게 스노우볼 스노우덕 오리 눈사람 만들기
# 850
# https://smartstore.naver.com/main/products/5321647474?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=10ae67334085421083d695ddc5b55d52&NaPm=ci%3D10ae67334085421083d695ddc5b55d52%7Cct%3Dm4xmqq35%7Ctr%3Dnslsl%7Csn%3D827991%7Chk%3D8d6922a1f6b29446bfc69439fa4c44d229486b4d
# 초대형 오리눈집게 눈오리메이커 빅사이즈 41cm
# 6,300
# https://smartstore.naver.com/main/products/7576774685?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=117ae703605c49d48c1f520fc2117d06&NaPm=ci%3D117ae703605c49d48c1f520fc2117d06%7Cct%3Dm4xmqq35%7Ctr%3Dnslsl%7Csn%3D6740514%7Chk%3D20c47058a6da3b3b467fc8a4a7713ed0671c0172
# 오리 스노우볼 제조기 (소)(1p) 눈 만들기 뭉치 집게
# 600
# https://smartstore.naver.com/main/products/9454919949?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=a709511efa2d4f6ca757a5914a076aad&NaPm=ci%3Da709511efa2d4f6ca757a5914a076aad%7Cct%3Dm4xmqq35%7Ctr%3Dnslsl%7Csn%3D304911%7Chk%3D7fdb07a9c4ab47b142c85e60aeeecb91dbc31c51
# 스노우볼메이커 눈오리만들기 오리집게
# 2,000
# https://smartstore.naver.com/main/products/6037330106?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=7fa2a29fca144d4e8ce886b9ba2106ae&NaPm=ci%3D7fa2a29fca144d4e8ce886b9ba2106ae%7Cct%3Dm4xmqq35%7Ctr%3Dnslsl%7Csn%3D1228832%7Chk%3Dd35c529b3612faa845a37cccd14315519f7495a4
# 초대형 뽀로로 눈집게 스노우볼메이커 눈놀이 눈오리 집게
# 6,800
# https://smartstore.naver.com/main/products/7778804356?nl-query=%EB%88%88%EC%98%A4%EB%A6%AC&nl-au=a0086498b64e42f3917a7ce6c4fa1c79&NaPm=ci%3Da0086498b64e42f3917a7ce6c4fa1c79%7Cct%3Dm4xmqq35%7Ctr%3Dnslsl%7Csn%3D5706684%7Chk%3D9a40a86c7dc958cf1b4548f6498e2de3a5bf88f5
