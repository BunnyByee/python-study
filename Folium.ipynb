# %%
import folium

# %%
m = folium.Map(location=[37.547631, 126.942463], zoom_start=15)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_886f93587c9dad3e6266d96bf17ef7a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_886f93587c9dad3e6266d96bf17ef7a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_886f93587c9dad3e6266d96bf17ef7a2 = L.map(
#                 &quot;map_886f93587c9dad3e6266d96bf17ef7a2&quot;,
#                 {
#                     center: [37.547631, 126.942463],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_201ac053b2634734bbda86f4ba1fc6c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_201ac053b2634734bbda86f4ba1fc6c8.addTo(map_886f93587c9dad3e6266d96bf17ef7a2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[37.531926334244034, 126.91421892157778], zoom_start=15,
                width=800, height=600)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([37.531926334244034, 126.91421892157778], popup='팝업', tooltip='툴팁').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_a42ae241806157a66fd36273fb596feb = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_edbe844a4395109f50d664f64072593a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32314f27432bb6d075b7b468beaef93 = $(`&lt;div id=&quot;html_a32314f27432bb6d075b7b468beaef93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_edbe844a4395109f50d664f64072593a.setContent(html_a32314f27432bb6d075b7b468beaef93);
#
#
#
#         marker_a42ae241806157a66fd36273fb596feb.bindPopup(popup_edbe844a4395109f50d664f64072593a)
#         ;
#
#
#
#
#             marker_a42ae241806157a66fd36273fb596feb.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99682f2d30c80c3e37df2cf9b7d87130 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_d69555e1914c4ac0f565a25f9a314402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a77ef0263fe0eb7e508da3afde2cb89b = $(`&lt;div id=&quot;html_a77ef0263fe0eb7e508da3afde2cb89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_d69555e1914c4ac0f565a25f9a314402.setContent(html_a77ef0263fe0eb7e508da3afde2cb89b);
#
#
#
#         marker_99682f2d30c80c3e37df2cf9b7d87130.bindPopup(popup_d69555e1914c4ac0f565a25f9a314402)
#         ;
#
#
#
#
#             marker_99682f2d30c80c3e37df2cf9b7d87130.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([37.531926334244034, 126.91421892157778], popup='팝업', tooltip='툴팁',
                icon=folium.Icon(color='black', icon="fa-solid fa-folder", prefix='fa-solid')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_a42ae241806157a66fd36273fb596feb = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_edbe844a4395109f50d664f64072593a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32314f27432bb6d075b7b468beaef93 = $(`&lt;div id=&quot;html_a32314f27432bb6d075b7b468beaef93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_edbe844a4395109f50d664f64072593a.setContent(html_a32314f27432bb6d075b7b468beaef93);
#
#
#
#         marker_a42ae241806157a66fd36273fb596feb.bindPopup(popup_edbe844a4395109f50d664f64072593a)
#         ;
#
#
#
#
#             marker_a42ae241806157a66fd36273fb596feb.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99682f2d30c80c3e37df2cf9b7d87130 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_d69555e1914c4ac0f565a25f9a314402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a77ef0263fe0eb7e508da3afde2cb89b = $(`&lt;div id=&quot;html_a77ef0263fe0eb7e508da3afde2cb89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_d69555e1914c4ac0f565a25f9a314402.setContent(html_a77ef0263fe0eb7e508da3afde2cb89b);
#
#
#
#         marker_99682f2d30c80c3e37df2cf9b7d87130.bindPopup(popup_d69555e1914c4ac0f565a25f9a314402)
#         ;
#
#
#
#
#             marker_99682f2d30c80c3e37df2cf9b7d87130.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_6bb90591efde3b54d55067a61c045ba9 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var icon_fc08f1870c1534b50ecaaf7dd0f1b7fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-folder&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6bb90591efde3b54d55067a61c045ba9.setIcon(icon_fc08f1870c1534b50ecaaf7dd0f1b7fb);
#
#
#         var popup_a5ad5f38d312e0877c6db9a081cd3ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9587055820fd47b6cfe45b5f90d30654 = $(`&lt;div id=&quot;html_9587055820fd47b6cfe45b5f90d30654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_a5ad5f38d312e0877c6db9a081cd3ad3.setContent(html_9587055820fd47b6cfe45b5f90d30654);
#
#
#
#         marker_6bb90591efde3b54d55067a61c045ba9.bindPopup(popup_a5ad5f38d312e0877c6db9a081cd3ad3)
#         ;
#
#
#
#
#             marker_6bb90591efde3b54d55067a61c045ba9.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_071376ab184ee83b10dff8601b3b68b8 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23

# %%
m.add_child(folium.ClickForMarker(popup='클릭'))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_a42ae241806157a66fd36273fb596feb = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_edbe844a4395109f50d664f64072593a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32314f27432bb6d075b7b468beaef93 = $(`&lt;div id=&quot;html_a32314f27432bb6d075b7b468beaef93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_edbe844a4395109f50d664f64072593a.setContent(html_a32314f27432bb6d075b7b468beaef93);
#
#
#
#         marker_a42ae241806157a66fd36273fb596feb.bindPopup(popup_edbe844a4395109f50d664f64072593a)
#         ;
#
#
#
#
#             marker_a42ae241806157a66fd36273fb596feb.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99682f2d30c80c3e37df2cf9b7d87130 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_d69555e1914c4ac0f565a25f9a314402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a77ef0263fe0eb7e508da3afde2cb89b = $(`&lt;div id=&quot;html_a77ef0263fe0eb7e508da3afde2cb89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_d69555e1914c4ac0f565a25f9a314402.setContent(html_a77ef0263fe0eb7e508da3afde2cb89b);
#
#
#
#         marker_99682f2d30c80c3e37df2cf9b7d87130.bindPopup(popup_d69555e1914c4ac0f565a25f9a314402)
#         ;
#
#
#
#
#             marker_99682f2d30c80c3e37df2cf9b7d87130.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_6bb90591efde3b54d55067a61c045ba9 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var icon_fc08f1870c1534b50ecaaf7dd0f1b7fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-folder&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6bb90591efde3b54d55067a61c045ba9.setIcon(icon_fc08f1870c1534b50ecaaf7dd0f1b7fb);
#
#
#         var popup_a5ad5f38d312e0877c6db9a081cd3ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9587055820fd47b6cfe45b5f90d30654 = $(`&lt;div id=&quot;html_9587055820fd47b6cfe45b5f90d30654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_a5ad5f38d312e0877c6db9a081cd3ad3.setContent(html_9587055820fd47b6cfe45b5f90d30654);
#
#
#
#         marker_6bb90591efde3b54d55067a61c045ba9.bindPopup(popup_a5ad5f38d312e0877c6db9a081cd3ad3)
#         ;
#
#
#
#
#             marker_6bb90591efde3b54d55067a61c045ba9.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_071376ab184ee83b10dff8601b3b68b8 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23

# %%
m.add_child(folium.LatLngPopup())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_a42ae241806157a66fd36273fb596feb = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_edbe844a4395109f50d664f64072593a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32314f27432bb6d075b7b468beaef93 = $(`&lt;div id=&quot;html_a32314f27432bb6d075b7b468beaef93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_edbe844a4395109f50d664f64072593a.setContent(html_a32314f27432bb6d075b7b468beaef93);
#
#
#
#         marker_a42ae241806157a66fd36273fb596feb.bindPopup(popup_edbe844a4395109f50d664f64072593a)
#         ;
#
#
#
#
#             marker_a42ae241806157a66fd36273fb596feb.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99682f2d30c80c3e37df2cf9b7d87130 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_d69555e1914c4ac0f565a25f9a314402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a77ef0263fe0eb7e508da3afde2cb89b = $(`&lt;div id=&quot;html_a77ef0263fe0eb7e508da3afde2cb89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_d69555e1914c4ac0f565a25f9a314402.setContent(html_a77ef0263fe0eb7e508da3afde2cb89b);
#
#
#
#         marker_99682f2d30c80c3e37df2cf9b7d87130.bindPopup(popup_d69555e1914c4ac0f565a25f9a314402)
#         ;
#
#
#
#
#             marker_99682f2d30c80c3e37df2cf9b7d87130.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_6bb90591efde3b54d55067a61c045ba9 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var icon_fc08f1870c1534b50ecaaf7dd0f1b7fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-folder&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6bb90591efde3b54d55067a61c045ba9.setIcon(icon_fc08f1870c1534b50ecaaf7dd0f1b7fb);
#
#
#         var popup_a5ad5f38d312e0877c6db9a081cd3ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9587055820fd47b6cfe45b5f90d30654 = $(`&lt;div id=&quot;html_9587055820fd47b6cfe45b5f90d30654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_a5ad5f38d312e0877c6db9a081cd3ad3.setContent(html_9587055820fd47b6cfe45b5f90d30654);
#
#
#
#         marker_6bb90591efde3b54d55067a61c045ba9.bindPopup(popup_a5ad5f38d312e0877c6db9a081cd3ad3)
#         ;
#
#
#
#
#             marker_6bb90591efde3b54d55067a61c045ba9.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_071376ab184ee83b10dff8601b3b68b8 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23

# %%
folium.CircleMarker([37.531926334244034, 126.91421892157778],
                    radius=100,
                    color='#ff0000',
                    fill_color='#00ff00',
                    popup='CircleMarker').add_to(m)
folium.Circle([37.531926334244034, 126.91421892157778],
                    radius=90,
                    color='#0000ff',
                    fill_color='#ffffff',
                    popup='Circle').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_a42ae241806157a66fd36273fb596feb = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_edbe844a4395109f50d664f64072593a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32314f27432bb6d075b7b468beaef93 = $(`&lt;div id=&quot;html_a32314f27432bb6d075b7b468beaef93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_edbe844a4395109f50d664f64072593a.setContent(html_a32314f27432bb6d075b7b468beaef93);
#
#
#
#         marker_a42ae241806157a66fd36273fb596feb.bindPopup(popup_edbe844a4395109f50d664f64072593a)
#         ;
#
#
#
#
#             marker_a42ae241806157a66fd36273fb596feb.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99682f2d30c80c3e37df2cf9b7d87130 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_d69555e1914c4ac0f565a25f9a314402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a77ef0263fe0eb7e508da3afde2cb89b = $(`&lt;div id=&quot;html_a77ef0263fe0eb7e508da3afde2cb89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_d69555e1914c4ac0f565a25f9a314402.setContent(html_a77ef0263fe0eb7e508da3afde2cb89b);
#
#
#
#         marker_99682f2d30c80c3e37df2cf9b7d87130.bindPopup(popup_d69555e1914c4ac0f565a25f9a314402)
#         ;
#
#
#
#
#             marker_99682f2d30c80c3e37df2cf9b7d87130.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_6bb90591efde3b54d55067a61c045ba9 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var icon_fc08f1870c1534b50ecaaf7dd0f1b7fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-folder&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6bb90591efde3b54d55067a61c045ba9.setIcon(icon_fc08f1870c1534b50ecaaf7dd0f1b7fb);
#
#
#         var popup_a5ad5f38d312e0877c6db9a081cd3ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9587055820fd47b6cfe45b5f90d30654 = $(`&lt;div id=&quot;html_9587055820fd47b6cfe45b5f90d30654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_a5ad5f38d312e0877c6db9a081cd3ad3.setContent(html_9587055820fd47b6cfe45b5f90d30654);
#
#
#
#         marker_6bb90591efde3b54d55067a61c045ba9.bindPopup(popup_a5ad5f38d312e0877c6db9a081cd3ad3)
#         ;
#
#
#
#
#             marker_6bb90591efde3b54d55067a61c045ba9.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_071376ab184ee83b10dff8601b3b68b8 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23

# %%
import pandas as pd
data= pd.read_csv("택시승차대 현황.csv", encoding='cp949')
taxi = data.loc[:, ["위치명", "위도", "경도"]]
taxi
# Out:
#                           위치명         위도          경도
# 0               신용보증기금 마포지점 앞  37.545397  126.952564
# 1                 마포SK허브 빌딩 앞  37.552001  126.956512
# 2                   트라팰리스빌딩 앞  37.541448  126.947233
# 3     주식회사 메칸더브이 앞(혜당한방병원 건너)  37.548428  126.916896
# 4                 신의주 찹쌀순대점 앞  37.553712  126.935189
# 5   아이스페이스 빌딩 앞(하나은행 신촌지점 좌측)  37.555143  126.935994
# 6            동우빌딩 앞(키움참치 홍대점)  37.558086  126.927690
# 7                 홍반장감자탕전문점 앞  37.560302  126.905950
# 8       마포롯데캐슬 앞(공덕역 2번출구 방향)  37.544281  126.950622
# 9                    서울가든호텔 앞  37.540719  126.948352
# 10                 망원역 1번출구 앞  37.556207  126.910446

# %%
for index, row in taxi.iterrows():
    folium.Marker([row['위도'], row['경도']], popup=row['위치명'],
                icon=folium.Icon(color='red', icon="fa-solid fa-taxi", prefix='fa-solid')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01cc3b48748d23856dc0918bfe6e6301 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01cc3b48748d23856dc0918bfe6e6301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01cc3b48748d23856dc0918bfe6e6301 = L.map(
#                 &quot;map_01cc3b48748d23856dc0918bfe6e6301&quot;,
#                 {
#                     center: [37.531926334244034, 126.91421892157778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_a42ae241806157a66fd36273fb596feb = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_edbe844a4395109f50d664f64072593a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32314f27432bb6d075b7b468beaef93 = $(`&lt;div id=&quot;html_a32314f27432bb6d075b7b468beaef93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_edbe844a4395109f50d664f64072593a.setContent(html_a32314f27432bb6d075b7b468beaef93);
#
#
#
#         marker_a42ae241806157a66fd36273fb596feb.bindPopup(popup_edbe844a4395109f50d664f64072593a)
#         ;
#
#
#
#
#             marker_a42ae241806157a66fd36273fb596feb.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99682f2d30c80c3e37df2cf9b7d87130 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#         var popup_d69555e1914c4ac0f565a25f9a314402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a77ef0263fe0eb7e508da3afde2cb89b = $(`&lt;div id=&quot;html_a77ef0263fe0eb7e508da3afde2cb89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_d69555e1914c4ac0f565a25f9a314402.setContent(html_a77ef0263fe0eb7e508da3afde2cb89b);
#
#
#
#         marker_99682f2d30c80c3e37df2cf9b7d87130.bindPopup(popup_d69555e1914c4ac0f565a25f9a314402)
#         ;
#
#
#
#
#             marker_99682f2d30c80c3e37df2cf9b7d87130.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_6bb90591efde3b54d55067a61c045ba9 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var icon_fc08f1870c1534b50ecaaf7dd0f1b7fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;fa-solid fa-folder&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6bb90591efde3b54d55067a61c045ba9.setIcon(icon_fc08f1870c1534b50ecaaf7dd0f1b7fb);
#
#
#         var popup_a5ad5f38d312e0877c6db9a081cd3ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9587055820fd47b6cfe45b5f90d30654 = $(`&lt;div id=&quot;html_9587055820fd47b6cfe45b5f90d30654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;팝업&lt;/div&gt;`)[0];
#                 popup_a5ad5f38d312e0877c6db9a081cd3ad3.setContent(html_9587055820fd47b6cfe45b5f90d30654);
#
#
#
#         marker_6bb90591efde3b54d55067a61c045ba9.bindPopup(popup_a5ad5f38d312e0877c6db9a081cd3ad3)
#         ;
#
#
#
#
#             marker_6bb90591efde3b54d55067a61c045ba9.bindTooltip(
#                 `&lt;div&gt;
#                      툴팁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_6e03511c75d7f5b5aabc8bd63ddba7cd.addTo(map_01cc3b48748d23856dc0918bfe6e6301);
#
#
#             var marker_071376ab184ee83b10dff8601b3b68b8 = L.marker(
#                 [37.531926334244034, 126.91421892157778],
#                 {
# }
#             ).addTo(map_01cc3b48748d23
